# %%
import pandas as pd
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.20.3

# %%
df=pd.read_csv('Documents/car.csv')

# %%
len(df)
# Out:
# 11914

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
df.groupby('Make').Popularity.max()
# Out:
# Make
# Acura             204
# Alfa Romeo        113
# Aston Martin      259
# Audi             3105
# BMW              3916
# Bentley           520
# Bugatti           820
# Buick             155
# Cadillac         1624
# Chevrolet        1385
# Chrysler         1013
# Dodge            1851
# FIAT              819
# Ferrari          2774
# Ford             5657
# GMC               549
# Genesis            21
# HUMMER            130
# Honda            2202
# Hyundai          1439
# Infiniti          190
# Kia              1720
# Lamborghini      1158
# Land Rover        258
# Lexus             454
# Lincoln            61
# Lotus             613
# Maserati          238
# Maybach            67
# Mazda             586
# McLaren           416
# Mercedes-Benz     617
# Mitsubishi        436
# Nissan           2009
# Oldsmobile         26
# Plymouth          535
# Pontiac           210
# Porsche          1715
# Rolls-Royce        86
# Saab              376
# Scion             105
# ...

# %%
df.nlargest(columns='Popularity',n=3)
# Out:
#       Make     Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1331  Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1332  Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1333  Ford  Aerostar  1995  regular unleaded      155.0               6.0
#
#      Transmission Type     Driven_Wheels  Number of Doors Market Category  \
# 1331         AUTOMATIC  rear wheel drive              3.0             NaN
# 1332         AUTOMATIC  rear wheel drive              3.0             NaN
# 1333         AUTOMATIC   all wheel drive              3.0             NaN
#
#      Vehicle Size      Vehicle Style  highway MPG  city mpg  Popularity  MSRP
# 1331      Midsize      Cargo Minivan           22        16        5657  2000
# 1332      Midsize  Passenger Minivan           22        15        5657  2000
# 1333        Large  Passenger Minivan           18        14        5657  2000

# %%
df.value_counts('Make')
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
df.info('Model')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
np.count_nonzero(df['Make']=='Audi')
# Out:
# 328

# %%
(df.groupby('Make')['Model']).count()
# Out:
# Make
# Acura             252
# Alfa Romeo          5
# Aston Martin       93
# Audi              328
# BMW               334
# Bentley            74
# Bugatti             3
# Buick             196
# Cadillac          397
# Chevrolet        1123
# Chrysler          187
# Dodge             626
# FIAT               62
# Ferrari            69
# Ford              881
# GMC               515
# Genesis             3
# HUMMER             17
# Honda             449
# Hyundai           303
# Infiniti          330
# Kia               231
# Lamborghini        52
# Land Rover        143
# Lexus             202
# Lincoln           164
# Lotus              29
# Maserati           58
# Maybach            16
# Mazda             423
# McLaren             5
# Mercedes-Benz     353
# Mitsubishi        213
# Nissan            558
# Oldsmobile        150
# Plymouth           82
# Pontiac           186
# Porsche           136
# Rolls-Royce        31
# Saab              111
# Scion              60
# ...

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
(df.groupby('Model').Make).transform('count')
# Out:
# 0         1
# 1        16
# 2        16
# 3        16
# 4        16
#          ..
# 11909     7
# 11910     7
# 11911     7
# 11912     7
# 11913     1
# Name: Make, Length: 11914, dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
median=(df['Engine Cylinders']).median()
print(median)
# Out:
# 6.0

# %% [markdown]
# median=(df['Engine Cylinders']).median()
# print(median)
# (df['Engine Cylinders']).describe()

# %%
(df['Engine Cylinders']).describe()
# Out:
# count    11884.000000
# mean         5.628829
# std          1.780559
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: Engine Cylinders, dtype: float64

# %%
df.value_counts('Engine Cylinders')
# Out:
# Engine Cylinders
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# dtype: int64

# %%
df['Engine Cylinders']=(df['Engine Cylinders']).fillna(4.0)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
(df['Engine Cylinders']).describe()
# Out:
# count    11914.000000
# mean         5.624727
# std          1.780189
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: Engine Cylinders, dtype: float64

# %%
df['Engine Cylinders']
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
(df['Engine Cylinders']).describe()
# Out:
# count    11914.000000
# mean         5.624727
# std          1.780189
# min          0.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: Engine Cylinders, dtype: float64

# %%
(df['Engine Cylinders']).isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
median=(df['Engine Cylinders']).median()

# %%
print(median)
# Out:
# 6.0

# %%
(df.Make=='Lotus').sum()
# Out:
# 29

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
(df.Make=='Lotus').sum()
print(s)
# Out:
# [0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Name: Make, Length: 11914, dtype: bool]

# %%
X=df.loc[df.Make=='Lotus',['Engine HP','Engine Cylinders']].drop_duplicates()
X.values
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
XTX=X.T.dot(X)
XTX_inv=np.linalg.inv(XTX)
y=[1100,800,750,850,1300,1000,1000,1300,800]
h=XTX_inv.dot(X.T)
w=h.dot(y)
w
# Out:
# array([  4.59494481, -63.56432501])
